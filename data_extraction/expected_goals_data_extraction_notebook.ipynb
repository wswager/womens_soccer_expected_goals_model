# %% [markdown]
# <a href="https://colab.research.google.com/github/wswager/expected_goals/blob/main/data_extraction/expected_goals_data_extraction_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Capstone Project Submission**
#
# * Student Name: Wes Swager
# * Student Pace: Full Time
# * Instructor Name: Claude Fried
# * Scheduled Project Review Date/Time
#     * Unknown

# %% [markdown]
# # Data Extraction Notebook

# %% [markdown]
# <a id = 'proposal'></a>
# ### Proposal
#
# **Problem Statement**
#
# Create an expected goals metric using existing historical data which can be used to analyze future match data and provide specific recommendations to be utilized in following training to help improve the likelihood of goals.
#
# **Supervised Learning Target**
#
# Classification model which predicts the likelihood of a goal (percentage) given data features specific to the shot and preceding play.
#
# **Data Source**
#
# [StatsBomb Open Data](https://github.com/statsbomb/open-data)

# %% [markdown]
# # Packages

# %%
# Drive  and IO to access saved data
from google.colab import drive, files
drive.mount('/content/drive')

import io

# Pathlib for file retrieval
import pathlib
from pathlib import Path

# Pandas for Dataframes
import pandas as pd

# Numpy Math and for mathematical functions
import numpy as np

import warnings
warnings.filterwarnings('ignore')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Data

# %% [markdown]
# Data sourced from [StatsBomb Open Data](https://github.com/statsbomb/open-data)

# %% [markdown]
# # Extract Data from StatsBomb Open Data

# %% [markdown]
# ## Matches Data

# %%
# Identify target league match data within Statsbomb Open Data
# 37 - FA Womens Superleague
# 49 - NWSL

matches_path = '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/matches/'

target_leagues =['37/',
                 '49/']

matches_path_list = []
for tl in target_leagues:
    matches_path_list.extend(list((Path((matches_path + tl))).glob('*.json')))

# %%
matches_path_list
# Out:
# [PosixPath('/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/matches/37/4.json'),
#  PosixPath('/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/matches/37/42.json'),
#  PosixPath('/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/matches/37/90.json'),
#  PosixPath('/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/matches/49/3.json')]

# %%
# Create dataframe from target league match data

matches_list = [] 
for mpl in matches_path_list:
    matches_data = pd.read_json(mpl)
    matches_list.append(matches_data)

matches_df = pd.concat(matches_list,
                       ignore_index = True)

# %%
matches_df.head()
# Out:
#    match_id  ...                                            referee
# 0     19743  ...  {'id': 898, 'name': 'A. Fearn', 'country': {'i...
# 1     19740  ...  {'id': 568, 'name': 'J. Packman', 'country': {...
# 2     19716  ...  {'id': 567, 'name': 'H. Conley', 'country': {'...
# 3     19800  ...  {'id': 915, 'name': 'R. Whitton', 'country': {...
# 4     19739  ...                                                NaN
#
# [5 rows x 18 columns]

# %%
matches_df.to_csv('/content/drive/MyDrive/flatiron/expected_goals/data_extraction/matches_df.csv')

# %% [markdown]
# ## Events Data

# %%
# Identifying target league match events data within Statsbomb Open Data

matches_int = matches_df['match_id'].values

matches = []
for int in matches_int:
    matches.append(str(int))


events_path = '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/'

events_matches_path = []
for m in matches:
    events_matches_path.append(events_path + m + '.json')

# %%
events_matches_path
# Out:
# ['/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19743.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19740.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19716.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19800.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19739.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19734.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19748.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19822.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19766.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19785.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19749.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19751.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19764.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19773.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19783.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19736.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19747.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19769.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19770.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19757.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19742.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19777.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19758.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19802.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19803.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19746.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19811.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19805.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19745.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19752.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19772.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19775.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19760.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19787.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19733.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19765.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19792.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19732.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19744.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19799.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19730.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19753.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19735.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19717.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19718.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19720.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19719.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19715.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19723.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19722.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19727.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19731.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19714.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19728.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19726.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19725.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19738.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19759.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19750.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19761.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19762.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19763.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19768.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19767.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19776.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19794.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19820.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19737.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19790.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19793.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19789.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19791.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19796.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19795.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19797.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19780.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19781.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19779.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19798.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19782.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19784.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19786.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19774.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19755.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19806.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19807.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19788.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19808.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19804.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19813.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19816.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19809.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19810.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19815.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19817.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19818.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19819.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19821.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19801.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19741.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19756.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19754.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19724.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19814.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19729.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19778.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/19771.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275054.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275072.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275085.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275113.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275142.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275099.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275057.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275075.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275077.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275036.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275117.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275092.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275040.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275045.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275093.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275153.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275097.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275122.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275084.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275089.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275116.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275127.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275104.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275052.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275037.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275027.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275078.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275080.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275098.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275156.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275120.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275028.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275150.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275139.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275070.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275051.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275063.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275050.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275029.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275090.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275042.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275108.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275082.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275138.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275049.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275132.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275146.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275061.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275096.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275033.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275107.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275130.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275034.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275026.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275041.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275094.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275044.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275157.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275106.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275144.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275105.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275073.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275038.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275131.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275062.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275048.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275121.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275065.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275079.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275103.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275140.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275126.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275102.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275109.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275091.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275030.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275133.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275083.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275086.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275137.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275056.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275074.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275136.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275151.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275154.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275088.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/2275110.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/3764234.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/7494.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/7486.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/7497.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/7430.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/7443.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/7521.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/7492.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/7524.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/7496.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/7523.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/7444.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/7520.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/7493.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/7500.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/7519.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/7473.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/7522.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/7484.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/7475.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/7457.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/7445.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/7490.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/7482.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/7479.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/7478.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/7456.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/7471.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/7477.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/7472.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/7474.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/7487.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/7485.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/7483.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/7476.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/7451.json',
#  '/content/drive/MyDrive/flatiron/expected_goals/statsbomb_open_data/events/7480.json']

# %%
# Create dataframe from target league match event data

events_list = [] 
for emp in events_matches_path:
    events_data = pd.read_json(emp)
    events_list.append(events_data)

events_df = pd.concat(events_list,
                      ignore_index = True)

# %%
# Drop events not associated with shots from events_df

events_shots_df = events_df[events_df['shot'].notna()]

# %%
events_shots_df.head()
# Out:
#                                        id  index  ...  half_start half_end
# 257  8f5a3b7c-db0b-42ec-bac0-adc0bedca2ea    258  ...         NaN      NaN
# 541  60ead7a6-4aa2-41ab-85a1-21357f50e4e0    542  ...         NaN      NaN
# 613  f68deb6f-0711-4b9d-8081-122dc3722c55    614  ...         NaN      NaN
# 876  f301190f-cc0a-4f16-8278-27e5279ea24e    877  ...         NaN      NaN
# 891  8558535e-b1ee-4f53-b003-1b5fba2712bd    892  ...         NaN      NaN
#
# [5 rows x 42 columns]

# %%
events_shots_df.to_csv('/content/drive/MyDrive/flatiron/expected_goals/data_extraction/events_shots_df.csv')

# %% [markdown]
# Continued in [expected_goals_data_organization_notebook](https://github.com/wswager/expected_goals/blob/main/data_organization/expected_goals_data_organization_notebook.ipynb)
