# %% [markdown]
# ### Capstone Project Submission
#
# * Student Name: Wes Swager
# * Student Pace: Full Time
# * Instructor Name: Claude Fried
# * Scheduled Project Review Date/Time
#     * Unknown

# %% [markdown]
# # Data Extraction Notebook

# %% [markdown]
# <a id = 'proposal'></a>
# ### Proposal
#
# **Problem Statement**
#
# Create an expected goals metric using existing historical data which can be used to analyze future match data and provide specific recommendations to be utilized in following training to help improve the likelihood of goals.
#
# **Supervised Learning Target**
#
# Classification model which predicts the likelihood of a goal (percentage) given data features specific to the shot and preceding play.
#
# **Data Source**
#
# [StatsBomb Open Data](https://github.com/statsbomb/open-data)

# %% [markdown]
# # Contents
#
# * **[Proposal](#proposal)**
# * **[Data](#data)**
# * **[Packages](#packages)**
# * **[Extract Data from StatsBomb open Data](#extract_data)**
#     * **[Matches Data](#matches_data)**
#     * **[Events Data](#events_data)**
# * **[Extract Features from Nested Dictionaries](#extract_features)**
#     * **[Shot-Specific Data](#shot_data)**
#     * **[Shot-Specific Features](#shot_features)**
#     * **[Assist-Specific Features](#assist_features)**
# * **[Extracted Data](#extracted_data)**

# %% [markdown]
# <a id = 'packages'></a>
# # Packages

# %%
# Glob for file retrieval
import glob

# Pandas for Dataframes
import pandas as pd

# Numpy and for mathematical functions
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <a id = 'data'></a>
# # Data

# %% [markdown]
# Data sourced from [StatsBomb Open Data](https://github.com/statsbomb/open-data)

# %% [markdown]
# <a id = 'extract_data'></a>
# # Extract Data from StatsBomb Open Data

# %% [markdown]
# <a id = 'matches_data'></a>
# ## Matches Data

# %%
# Identify target league match data within Statsbomb Open Data
# 37 - FA Womens Superleague
# 49 - NWSL

matches_path = 'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/matches/'

target_leagues =['37',
                 '49']

matches_path_list = []
for tl in target_leagues:
    matches_path_list.extend(glob.glob(matches_path + tl + '/*.json'))

# %%
matches_path_list
# Out:
# ['C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/matches/37\\4.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/matches/37\\42.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/matches/37\\90.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/matches/49\\3.json']

# %%
# Create dataframe from target league match data

matches_list = [] 
for mpl in matches_path_list:
    matches_data = pd.read_json(mpl)
    matches_list.append(matches_data)

matches_df = pd.concat(matches_list,
                       ignore_index = True)

# %%
matches_df.head()
# Out:
#    match_id  match_date      kick_off  \
# 0     19743  2018-10-21  13:30:00.000
# 1     19740  2018-10-21  16:00:00.000
# 2     19716  2018-09-09  15:00:00.000
# 3     19800  2019-03-14  20:30:00.000
# 4     19739  2018-10-21  15:00:00.000
#
#                                          competition  \
# 0  {'competition_id': 37, 'country_name': 'Englan...
# 1  {'competition_id': 37, 'country_name': 'Englan...
# 2  {'competition_id': 37, 'country_name': 'Englan...
# 3  {'competition_id': 37, 'country_name': 'Englan...
# 4  {'competition_id': 37, 'country_name': 'Englan...
#
#                                          season  \
# 0  {'season_id': 4, 'season_name': '2018/2019'}
# 1  {'season_id': 4, 'season_name': '2018/2019'}
# 2  {'season_id': 4, 'season_name': '2018/2019'}
# 3  {'season_id': 4, 'season_name': '2018/2019'}
# 4  {'season_id': 4, 'season_name': '2018/2019'}
#
#                                            home_team  \
# 0  {'home_team_id': 969, 'home_team_name': 'Birmi...
# 1  {'home_team_id': 972, 'home_team_name': 'West ...
# 2  {'home_team_id': 974, 'home_team_name': 'Readi...
# 3  {'home_team_id': 968, 'home_team_name': 'Arsen...
# 4  {'home_team_id': 965, 'home_team_name': 'Brigh...
#
#                                            away_team  home_score  away_score  \
# 0  {'away_team_id': 971, 'away_team_name': 'Chels...           0           0
# 1  {'away_team_id': 966, 'away_team_name': 'Liver...           0           1
# 2  {'away_team_id': 970, 'away_team_name': 'Yeovi...           4           0
# 3  {'away_team_id': 973, 'away_team_name': 'Brist...           4           0
# 4  {'away_team_id': 746, 'away_team_name': 'Manch...           0           6
#
#   match_status match_status_360                last_updated  last_updated_360  \
# 0    available       processing  2021-04-28T07:08:31.946271               NaN
# 1    available      unscheduled            2020-07-29T05:00               NaN
# 2    available      unscheduled            2020-07-29T05:00               NaN
# 3    available      unscheduled  2020-08-24T14:34:34.401523               NaN
# 4    available      unscheduled            2020-07-29T05:00               NaN
#
#                     metadata  match_week                    competition_stage  \
# 0  {'data_version': '1.0.3'}           6  {'id': 1, 'name': 'Regular Season'}
# 1  {'data_version': '1.0.3'}           6  {'id': 1, 'name': 'Regular Season'}
# 2  {'data_version': '1.0.3'}           1  {'id': 1, 'name': 'Regular Season'}
# 3  {'data_version': '1.1.0'}          18  {'id': 1, 'name': 'Regular Season'}
# 4  {'data_version': '1.0.3'}           6  {'id': 1, 'name': 'Regular Season'}
#
#                                              stadium  \
# 0  {'id': 5332, 'name': 'SportNation.bet Stadium'...
# 1  {'id': 4062, 'name': 'The Rush Green Stadium',...
# 2  {'id': 577, 'name': 'Adams Park', 'country': {...
# 3  {'id': 456, 'name': 'Meadow Park', 'country': ...
# 4                                                NaN
#
#                                              referee
# 0  {'id': 898, 'name': 'A. Fearn', 'country': {'i...
# 1  {'id': 568, 'name': 'J. Packman', 'country': {...
# 2  {'id': 567, 'name': 'H. Conley', 'country': {'...
# 3  {'id': 915, 'name': 'R. Whitton', 'country': {...
# 4                                                NaN

# %%
matches_df.to_csv(r'C:\Users\westi\Documents\github\expected_goals\data\saved_dataframes\data_extraction\matches_df.csv')
# %store matches_df
# Out:
# Stored 'matches_df' (DataFrame)

# %% [markdown]
# <a id = 'events_data'></a>
# ## Events Data

# %%
# Identifying target league match events data within Statsbomb Open Data

matches_int = matches_df['match_id'].values

matches = []
for int in matches_int:
    matches.append(str(int))

events_path = 'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/'

events_matches_path = []
for m in matches:
    events_matches_path.append(events_path + m + '.json')

# %%
events_matches_path
# Out:
# ['C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19743.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19740.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19716.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19800.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19739.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19734.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19748.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19822.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19766.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19785.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19749.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19751.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19764.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19773.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19783.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19736.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19747.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19769.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19770.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19757.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19742.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19777.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19758.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19802.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19803.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19746.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19811.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19805.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19745.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19752.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19772.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19775.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19760.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19787.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19733.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19765.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19792.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19732.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19744.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19799.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19730.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19753.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19735.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19717.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19718.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19720.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19719.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19715.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19723.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19722.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19727.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19731.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19714.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19728.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19726.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19725.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19738.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19759.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19750.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19761.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19762.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19763.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19768.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19767.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19776.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19794.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19820.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19737.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19790.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19793.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19789.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19791.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19796.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19795.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19797.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19780.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19781.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19779.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19798.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19782.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19784.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19786.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19774.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19755.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19806.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19807.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19788.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19808.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19804.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19813.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19816.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19809.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19810.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19815.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19817.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19818.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19819.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19821.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19801.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19741.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19756.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19754.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19724.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19814.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19729.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19778.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/19771.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275054.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275072.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275085.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275113.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275142.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275099.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275057.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275075.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275077.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275036.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275117.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275092.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275040.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275045.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275093.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275153.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275097.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275122.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275084.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275089.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275116.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275127.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275104.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275052.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275037.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275027.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275078.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275080.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275098.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275156.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275120.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275028.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275150.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275139.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275070.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275051.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275063.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275050.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275029.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275090.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275042.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275108.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275082.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275138.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275049.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275132.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275146.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275061.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275096.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275033.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275107.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275130.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275034.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275026.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275041.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275094.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275044.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275157.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275106.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275144.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275105.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275073.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275038.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275131.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275062.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275048.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275121.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275065.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275079.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275103.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275140.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275126.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275102.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275109.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275091.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275030.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275133.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275083.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275086.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275137.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275056.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275074.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275136.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275151.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275154.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275088.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/2275110.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/3764234.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/7494.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/7486.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/7497.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/7430.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/7443.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/7521.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/7492.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/7524.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/7496.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/7523.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/7444.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/7520.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/7493.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/7500.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/7519.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/7473.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/7522.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/7484.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/7475.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/7457.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/7445.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/7490.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/7482.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/7479.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/7478.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/7456.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/7471.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/7477.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/7472.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/7474.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/7487.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/7485.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/7483.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/7476.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/7451.json',
#  'C:/Users/westi/Documents/github/expected_goals/data/statsbomb_open_data/events/7480.json']

# %%
# Create dataframe from target league match event data

events_list = [] 
for file in events_matches_path:
    data = pd.read_json(file)
    events_list.append(data)

events_df = pd.concat(events_list,
                      ignore_index = True)

# %%
# Drop events not associated with shots from events_df

events_shots_df = events_df[events_df['shot'].notna()]

# %%
events_shots_df.head()
# Out:
#                                        id  index  period  \
# 257  8f5a3b7c-db0b-42ec-bac0-adc0bedca2ea    258       1
# 541  60ead7a6-4aa2-41ab-85a1-21357f50e4e0    542       1
# 613  f68deb6f-0711-4b9d-8081-122dc3722c55    614       1
# 876  f301190f-cc0a-4f16-8278-27e5279ea24e    877       1
# 891  8558535e-b1ee-4f53-b003-1b5fba2712bd    892       1
#
#                   timestamp  minute  second                        type  \
# 257 2021-06-05 00:04:38.609       4      38  {'id': 16, 'name': 'Shot'}
# 541 2021-06-05 00:11:45.046      11      45  {'id': 16, 'name': 'Shot'}
# 613 2021-06-05 00:18:03.461      18       3  {'id': 16, 'name': 'Shot'}
# 876 2021-06-05 00:23:11.935      23      11  {'id': 16, 'name': 'Shot'}
# 891 2021-06-05 00:23:45.810      23      45  {'id': 16, 'name': 'Shot'}
#
#      possession                             possession_team  \
# 257          11          {'id': 971, 'name': 'Chelsea FCW'}
# 541          24          {'id': 971, 'name': 'Chelsea FCW'}
# 613          29          {'id': 971, 'name': 'Chelsea FCW'}
# 876          43  {'id': 969, 'name': 'Birmingham City WFC'}
# 891          44          {'id': 971, 'name': 'Chelsea FCW'}
#
#                             play_pattern  ... foul_won  clearance  \
# 257    {'id': 1, 'name': 'Regular Play'}  ...      NaN        NaN
# 541  {'id': 3, 'name': 'From Free Kick'}  ...      NaN        NaN
# 613    {'id': 1, 'name': 'Regular Play'}  ...      NaN        NaN
# 876  {'id': 7, 'name': 'From Goal Kick'}  ...      NaN        NaN
# 891  {'id': 7, 'name': 'From Goal Kick'}  ...      NaN        NaN
#
#     injury_stoppage miscontrol block out bad_behaviour player_off half_start  \
# 257             NaN        NaN   NaN NaN           NaN        NaN        NaN
# 541             NaN        NaN   NaN NaN           NaN        NaN        NaN
# 613             NaN        NaN   NaN NaN           NaN        NaN        NaN
# 876             NaN        NaN   NaN NaN           NaN        NaN        NaN
# 891             NaN        NaN   NaN NaN           NaN        NaN        NaN
#
#      half_end
# 257       NaN
# 541       NaN
# 613       NaN
# 876       NaN
# 891       NaN
#
# [5 rows x 42 columns]

# %%
events_shots_df.to_csv(r'C:\Users\westi\Documents\github\expected_goals\data\saved_dataframes\data_extraction\events_shots_df.csv')
# %store events_shots_df
# Out:
# Stored 'events_shots_df' (DataFrame)

# %% [markdown]
# <a id = 'shot_data'></a>
# # Extract Shot-Specific Data

# %%
# Extracting shot specific data from 
# events_df nested dictionaries

shots_df = events_shots_df[['index',
                            'timestamp',
                            'shot',
                            'location',
                            'player',
                            'possession_team']]

# %%
shots_df.head()
# Out:
#      index               timestamp  \
# 257    258 2021-06-05 00:04:38.609
# 541    542 2021-06-05 00:11:45.046
# 613    614 2021-06-05 00:18:03.461
# 876    877 2021-06-05 00:23:11.935
# 891    892 2021-06-05 00:23:45.810
#
#                                                   shot       location  \
# 257  {'statsbomb_xg': 0.26615402, 'end_location': [...  [109.0, 46.0]
# 541  {'one_on_one': True, 'statsbomb_xg': 0.0935205...  [113.0, 35.0]
# 613  {'statsbomb_xg': 0.036171142, 'end_location': ...   [94.0, 43.0]
# 876  {'statsbomb_xg': 0.016625367000000002, 'end_lo...   [86.0, 34.0]
# 891  {'statsbomb_xg': 0.030716168000000002, 'end_lo...   [94.0, 33.0]
#
#                                        player  \
# 257   {'id': 4641, 'name': 'Francesca Kirby'}
# 541  {'id': 15550, 'name': 'Bethany England'}
# 613       {'id': 4638, 'name': 'Drew Spence'}
# 876     {'id': 10193, 'name': 'Chloe Arthur'}
# 891  {'id': 15550, 'name': 'Bethany England'}
#
#                                 possession_team
# 257          {'id': 971, 'name': 'Chelsea FCW'}
# 541          {'id': 971, 'name': 'Chelsea FCW'}
# 613          {'id': 971, 'name': 'Chelsea FCW'}
# 876  {'id': 969, 'name': 'Birmingham City WFC'}
# 891          {'id': 971, 'name': 'Chelsea FCW'}

# %%
shots_df.to_csv(r'C:\Users\westi\Documents\github\expected_goals\data\saved_dataframes\data_extraction\shots_df.csv')
# %store shots_df
# Out:
# Stored 'shots_df' (DataFrame)

# %% [markdown]
# <a id = 'extract_features'></a>
# # Extract Features from Nested Dictionaries

# %% [markdown]
# <a id = 'shot_features'></a>
# ## Shot-Specific Features

# %%
# Defining and extracting shot specific features from
# shots_df nested dictionaries

# Shot location
location_list = []
location_list.extend(list(shots_df['location'].values))

# Create dataframe of shot features
extracted_data = pd.DataFrame(location_list)
extracted_data.columns = ['location_x',
                          'location_y']

# Shot timestamp
time_list = []
time_list.extend(list(shots_df['timestamp'].values))
extracted_data['time'] = time_list

# StatBombs' xG metric
statsbomb_xg_list = []
for i in range(0, len(shots_df)):
    statsbomb_xg_list.append(shots_df.iloc[i]['shot']['statsbomb_xg'])
extracted_data['statsbomb_xg'] = statsbomb_xg_list

# Outcome of shot
outcome_list = []
for i in range(0, len(shots_df)):
    outcome_list.append(shots_df.iloc[i]['shot']['outcome']['name'])
extracted_data['outcome'] = outcome_list
        
# Player who shot
player_shot_list = []
for i in range(0, len(shots_df)):
    player_shot_list.append(shots_df.iloc[i]['player']['name'])
extracted_data['player_shot'] = player_shot_list
        
# Player who shot's team
team_list = []
for i in range(0, len(shots_df)):
    team_list.append(shots_df.iloc[i]['possession_team']['name'])
extracted_data['team'] = team_list
        
# Bodypart used to shoot
bodypart_list = []
for i in range(0, len(shots_df)):
    bodypart_list.append(shots_df.iloc[i]['shot']['body_part']['name'])
extracted_data['bodypart'] = bodypart_list
        
# Technique used for shot
technique_list = []
for i in range(0, len(shots_df)):
    technique_list.append(shots_df.iloc[i]['shot']['technique']['name'])
extracted_data['technique'] = technique_list
        
# If the shot was taken with the player's 1st-touch
first_time_list = []
for i in range(0, len(shots_df)):
    try:
        first_time_list.append(shots_df.iloc[i]['shot']['first_time'])
    except:
        first_time_list.append(False)
extracted_data['first_time'] = first_time_list
        
# State of play
state_of_play_list = []
for i in range(0, len(shots_df)):
    state_of_play_list.append(shots_df.iloc[i]['shot']['type']['name'])
extracted_data['state_of_play'] = state_of_play_list

# %%
extracted_data.head()
# Out:
#    location_x  location_y                    time  statsbomb_xg  outcome  \
# 0       109.0        46.0 2021-06-05 00:04:38.609      0.266154  Blocked
# 1       113.0        35.0 2021-06-05 00:11:45.046      0.093521    Off T
# 2        94.0        43.0 2021-06-05 00:18:03.461      0.036171    Saved
# 3        86.0        34.0 2021-06-05 00:23:11.935      0.016625    Off T
# 4        94.0        33.0 2021-06-05 00:23:45.810      0.030716    Off T
#
#        player_shot                 team    bodypart technique  first_time  \
# 0  Francesca Kirby          Chelsea FCW   Left Foot    Normal       False
# 1  Bethany England          Chelsea FCW        Head    Normal       False
# 2      Drew Spence          Chelsea FCW   Left Foot    Normal       False
# 3     Chloe Arthur  Birmingham City WFC   Left Foot    Normal       False
# 4  Bethany England          Chelsea FCW  Right Foot    Normal       False
#
#   state_of_play
# 0     Open Play
# 1     Open Play
# 2     Open Play
# 3     Open Play
# 4     Open Play

# %% [markdown]
# <a id = 'assist_features'></a>
# ## Assist-Specific Features

# %%
# Defining and extracting features specific to
# the pass which lead to the shot from
# shots_df nested dictionaries

# Add pass features to dataframe

# Type of pass which lead to the shot
assist_list = []

for i in range(0, len(shots_df)):
    try:
        # Define 'key pass' within shots_df and events_df
        key_pass = events_df['id'] == shots_df.iloc[i]['shot']['key_pass_id']
        
        # Define assist in events_df
        assist_id = events_df[key_pass].dropna(axis = 'columns')['pass']
        
        assist_list.append(assist_id.iloc[0]['height']['name'])
        
    except KeyError:
        assist_list.append(np.nan)
        
extracted_data['assist'] = assist_list

# Second alternative source for type of pass
# which lead to the shot
assist2_list = []

for i in range(0, len(shots_df)):
    try:
        # Define 'key pass' within shots_df and events_df
        key_pass = events_df['id'] == shots_df.iloc[i]['shot']['key_pass_id']
        
        # Define assist in events_df
        assist_id = events_df[key_pass].dropna(axis = 'columns')['pass']
        
        assist2_list.append(assist_id.iloc[0]['technique']['name'])
        
    except KeyError:
        assist2_list.append(np.nan)

extracted_data['assist2'] = assist2_list

# Third alternative source for type of pass
# which lead to the shot
assist3_list = []

for i in range(0, len(shots_df)):
    try:
        # Define 'key pass' within shots_df and events_df
        key_pass = events_df['id'] == shots_df.iloc[i]['shot']['key_pass_id']
        
        # Define assist in events_df
        assist_id = events_df[key_pass].dropna(axis = 'columns')['pass']
        
        if 'cross' in assist_id.iloc[0]:
            assist3_list.append('Cross')
        
        elif 'cut_back' in assist_id.iloc[0]:
            assist3_list.append('Cut Back')
        
        elif 'through_ball' in assist_id.iloc[0]:
            assist3_list.append('Through Ball')
        
        else:
            assist3_list.append(np.nan)
        
    except KeyError:
        assist3_list.append(np.nan)

extracted_data['assist3'] = assist3_list

# State of play for pass which lead to the shot
assist_state_of_play_list = []
for i in range(0, len(shots_df)):
    try:
        # Define 'key pass' within shots_df and events_df
        key_pass = events_df['id'] == shots_df.iloc[i]['shot']['key_pass_id']
        
        # Define assist in events_df
        assist_play_id = events_df[key_pass]['play_pattern']
        
        assist_state_of_play_list.append(assist_play_id.iloc[0]['name'])

    except KeyError:
        assist_state_of_play_list.append(np.nan)

extracted_data['assist_state_of_play'] = assist_state_of_play_list

# %% [markdown]
# <a id = 'extracted_data'></a>
# # Extracted Data

# %%
extracted_data.head()
# Out:
#    location_x  location_y                    time  statsbomb_xg  outcome  \
# 0       109.0        46.0 2021-06-05 00:04:38.609      0.266154  Blocked
# 1       113.0        35.0 2021-06-05 00:11:45.046      0.093521    Off T
# 2        94.0        43.0 2021-06-05 00:18:03.461      0.036171    Saved
# 3        86.0        34.0 2021-06-05 00:23:11.935      0.016625    Off T
# 4        94.0        33.0 2021-06-05 00:23:45.810      0.030716    Off T
#
#        player_shot                 team    bodypart technique  first_time  \
# 0  Francesca Kirby          Chelsea FCW   Left Foot    Normal       False
# 1  Bethany England          Chelsea FCW        Head    Normal       False
# 2      Drew Spence          Chelsea FCW   Left Foot    Normal       False
# 3     Chloe Arthur  Birmingham City WFC   Left Foot    Normal       False
# 4  Bethany England          Chelsea FCW  Right Foot    Normal       False
#
#   state_of_play       assist assist2 assist3 assist_state_of_play
# 0     Open Play  Ground Pass     NaN     NaN         Regular Play
# 1     Open Play    High Pass     NaN     NaN       From Free Kick
# 2     Open Play  Ground Pass     NaN     NaN         Regular Play
# 3     Open Play  Ground Pass     NaN     NaN       From Goal Kick
# 4     Open Play  Ground Pass     NaN     NaN       From Goal Kick

# %%
extracted_data.to_csv(r'C:\Users\westi\Documents\github\expected_goals\data\saved_dataframes\data_extraction\extracted_data.csv')
# %store extracted_data
# Out:
# Stored 'extracted_data' (DataFrame)
